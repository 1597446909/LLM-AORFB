# %%
from rdkit import Chem
import glob
files=glob.glob("*.mol")
SMILES={}
for file in files:
    # 读取mol文件并创建分子对象
    mol = Chem.MolFromMolFile(file,strictParsing=False)
    smiles = Chem.MolToSmiles(mol)
    SMILES[file.replace(".mol","")]=
    print(smiles)
# Out:
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [13:48:19] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# ...
